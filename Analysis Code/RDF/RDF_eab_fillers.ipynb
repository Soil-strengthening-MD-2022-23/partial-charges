# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:.6f}'.format
import matplotlib.pyplot as plt
plt.style.use('classic')
# %pylab inline
pylab.rcParams['figure.figsize'] = (14, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df1 = pd.read_csv("/users/shoumiksaha/desktop/MRS_Albert_Varun/rdf/Epf40/rdf_AB_eab07.txt", sep='\t', header=None,index_col=False,skiprows=2,names=['sigma', '0f', '25f', '50f', '75f', '100f'], usecols=['sigma', '0f', '25f', '50f', '75f', '100f'])
df2 = pd.read_csv("/users/shoumiksaha/desktop/MRS_Albert_Varun/rdf/Epf40/rdf_AB_eab10.txt", sep='\t', header=None,index_col=False,skiprows=2,names=['sigma', '0f', '25f', '50f', '75f', '100f'], usecols=['sigma', '0f', '25f', '50f', '75f', '100f'])
df3 = pd.read_csv("/users/shoumiksaha/desktop/MRS_Albert_Varun/rdf/Epf40/rdf_AB_eab15.txt", sep='\t', header=None,index_col=False,skiprows=2,names=['sigma', '0f', '25f', '50f', '75f', '100f'], usecols=['sigma', '0f', '25f', '50f', '75f', '100f'])
df4 = pd.read_csv("/users/shoumiksaha/desktop/MRS_Albert_Varun/rdf/Epf40/rdf_BB_eab07.txt", sep='\t', header=None,index_col=False,skiprows=2,names=['sigma', '0f', '25f', '50f', '75f', '100f'], usecols=['sigma', '0f', '25f', '50f', '75f', '100f'])
df5 = pd.read_csv("/users/shoumiksaha/desktop/MRS_Albert_Varun/rdf/Epf40/rdf_BB_eab10.txt", sep='\t', header=None,index_col=False,skiprows=2,names=['sigma', '0f', '25f', '50f', '75f', '100f'], usecols=['sigma', '0f', '25f', '50f', '75f', '100f'])
df6 = pd.read_csv("/users/shoumiksaha/desktop/MRS_Albert_Varun/rdf/Epf40/rdf_BB_eab15.txt", sep='\t', header=None,index_col=False,skiprows=2,names=['sigma', '0f', '25f', '50f', '75f', '100f'], usecols=['sigma', '0f', '25f', '50f', '75f', '100f'])

# %%
x=df1["sigma"].to_numpy()

y1=df1["0f"].to_numpy()
y2=df1["25f"].to_numpy()
y3=df1["50f"].to_numpy()
y4=df1["75f"].to_numpy()
y5=df1["100f"].to_numpy()

y6=df2["0f"].to_numpy()
y7=df2["25f"].to_numpy()
y8=df2["50f"].to_numpy()
y9=df2["75f"].to_numpy()
y10=df2["100f"].to_numpy()

y11=df3["0f"].to_numpy()
y12=df3["25f"].to_numpy()
y13=df3["50f"].to_numpy()
y14=df3["75f"].to_numpy()
y15=df3["100f"].to_numpy()

y16=df4["0f"].to_numpy()
y17=df4["25f"].to_numpy()
y18=df4["50f"].to_numpy()
y19=df4["75f"].to_numpy()
y20=df4["100f"].to_numpy()

y21=df5["0f"].to_numpy()
y22=df5["25f"].to_numpy()
y23=df5["50f"].to_numpy()
y24=df5["75f"].to_numpy()
y25=df5["100f"].to_numpy()

y26=df6["0f"].to_numpy()
y27=df6["25f"].to_numpy()
y28=df6["50f"].to_numpy()
y29=df6["75f"].to_numpy()
y30=df6["100f"].to_numpy()

# %%
fig, axs = plt.subplots(2, 3, sharex=True, figsize=(14,8))

fig.add_subplot(111, frameon=False)

plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)
plt.xlabel(r'Distance to monomer B ($\sigma$)', fontsize=15)
#plt.ylabel("common Y")

axs[0, 0].plot(x, y1,label="0% clay")
axs[0, 0].plot(x, y2,label="0.74% clay")
axs[0, 0].plot(x, y3,label="1.46% clay")
axs[0, 0].plot(x, y4,label="2.17% clay")
axs[0, 0].plot(x, y5,label="2.88% clay")
axs[0, 0].set_xlim([0.9,2.5])
axs[0, 0].set_ylim([-0.5,11])
axs[0, 0].set_ylabel('g(r) of monomer A', fontsize=15)
axs[0, 0].legend(loc="best", fontsize=10)
axs[0, 0].tick_params(axis='both', which='both', labelsize=10, labelbottom=True)

axs[0, 1].plot(x, y6,label="0% clay")
axs[0, 1].plot(x, y7,label="0.74% clay")
axs[0, 1].plot(x, y8,label="1.46% clay")
axs[0, 1].plot(x, y9,label="2.17% clay")
axs[0, 1].plot(x, y10,label="2.88% clay")
axs[0, 1].set_xlim([0.9,2.5])
axs[0, 1].set_ylim([-0.5,11])
axs[0, 1].legend(loc="best", fontsize=10)
axs[0, 1].tick_params(axis='both', which='both', labelsize=10, labelbottom=True)

axs[0, 2].plot(x, y11,label="0% clay")
axs[0, 2].plot(x, y12,label="0.74% clay")
axs[0, 2].plot(x, y13,label="1.46% clay")
axs[0, 2].plot(x, y14,label="2.17% clay")
axs[0, 2].plot(x, y15,label="2.88% clay")
axs[0, 2].set_xlim([0.9,2.5])
axs[0, 2].set_ylim([-0.5,11])
axs[0, 2].legend(loc="best", fontsize=10)
axs[0, 2].tick_params(axis='both', which='both', labelsize=10, labelbottom=True)

axs[1, 0].plot(x, y16,label="0% clay")
axs[1, 0].plot(x, y17,label="0.74% clay")
axs[1, 0].plot(x, y18,label="1.46% clay")
axs[1, 0].plot(x, y19,label="2.17% clay")
axs[1, 0].plot(x, y20,label="2.88% clay")
axs[1, 0].set_xlim([0.9,2.5])
axs[1, 0].set_ylim([-0.5,11])
axs[1, 0].set_ylabel('g(r) of monomer B', fontsize=15)
axs[1, 0].legend(loc="best", fontsize=10)
axs[1, 0].tick_params(axis='both', which='both', labelsize=10, labelbottom=True)

axs[1, 1].plot(x, y21,label="0% clay")
axs[1, 1].plot(x, y22,label="0.74% clay")
axs[1, 1].plot(x, y23,label="1.46% clay")
axs[1, 1].plot(x, y24,label="2.17% clay")
axs[1, 1].plot(x, y25,label="2.88% clay")
axs[1, 1].set_xlim([0.9,2.5])
axs[1, 1].set_ylim([-0.5,11])
axs[1, 1].legend(loc="best", fontsize=10)
axs[1, 1].tick_params(axis='both', which='both', labelsize=10, labelbottom=True)

axs[1, 2].plot(x, y26,label="0% clay")
axs[1, 2].plot(x, y27,label="0.74% clay")
axs[1, 2].plot(x, y28,label="1.46% clay")
axs[1, 2].plot(x, y29,label="2.17% clay")
axs[1, 2].plot(x, y30,label="2.88% clay")
axs[1, 2].set_xlim([0.9,2.5])
axs[1, 2].set_ylim([-0.5,11])
axs[1, 2].legend(loc="best", fontsize=10)
axs[0, 2].tick_params(axis='both', which='both', labelsize=10, labelbottom=True)

fig.savefig("rdf")
